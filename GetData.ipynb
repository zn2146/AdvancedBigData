# %%
import tushare as ts
import pandas as pd
data = ts.get_industry_classified()
data.head(5)
# Out:
#      code  name c_name
# 0  600051  宁波联合   综合行业
# 1  600209  罗顿发展   综合行业
# 2  600212  江泉实业   综合行业
# 3  600256  广汇能源   综合行业
# 4  600576  祥源文化   综合行业

# %%
fin_sector = data[data['c_name'] == '金融行业']
fin_sector[fin_sector['code'] == '601288']
# Out:
#         code  name c_name
# 1863  601288  农业银行   金融行业

# %%
fin_sector[fin_sector['code'] == '601398']
# Out:
#         code  name c_name
# 1868  601398  工商银行   金融行业

# %%
fin_sector[fin_sector['code'] == '601601']
# Out:
#         code  name c_name
# 1870  601601  中国太保   金融行业

# %%
fin_sector[fin_sector['code'] == '600000']
# Out:
#         code  name c_name
# 1843  600000  浦发银行   金融行业

# %%
price_nongye = pd.DataFrame({})
#price_nongye = ts.get_k_data('601288',start='2008-01-01')#1851
price_nongye = ts.get_hist_data('601288')
#price_nongye.to_csv("price_nongye.csv", encoding='utf-8', index=True)
#price_nongye

# %%
price_gongshang = pd.DataFrame({})
#price_gongshang = ts.get_k_data('601398',start='2008-01-01')#2455
price_gongshang = ts.get_hist_data('601398')#2455
#price_gongshang.to_csv("price_gongshang.csv", encoding='utf-8', index=True)
ts.get_k_data('601398',start='2008-01-01')
# Out:
#             date   open  close   high    low      volume    code
# 0     2008-01-02  5.014  4.977  5.063  4.903  1879107.14  601398
# 1     2008-01-03  4.958  4.964  4.970  4.835  2420670.49  601398
# 2     2008-01-04  4.927  4.940  5.020  4.884  1947919.82  601398
# 3     2008-01-07  4.927  4.909  4.940  4.853  2409263.23  601398
# 4     2008-01-08  4.940  4.983  5.057  4.921  3087408.67  601398
# 5     2008-01-09  4.989  5.007  5.038  4.946  1528114.33  601398
# 6     2008-01-10  5.026  5.007  5.063  4.927  2232785.31  601398
# 7     2008-01-11  5.026  5.112  5.137  5.020  3176113.71  601398
# 8     2008-01-14  5.155  5.106  5.174  5.050  2021688.11  601398
# 9     2008-01-15  5.106  5.001  5.112  4.983  1863791.34  601398
# 10    2008-01-16  4.927  4.872  4.946  4.860  2267749.24  601398
# 11    2008-01-17  4.829  4.749  4.927  4.669  2331914.96  601398
# 12    2008-01-18  4.921  4.841  5.100  4.761  1120667.39  601398
# ...

# %%
price_taibao = pd.DataFrame({})
#price_taibao = ts.get_k_data('601601',start='2008-01-01')#2465
price_taibao = ts.get_hist_data('601601')#2465
price_taibao.to_csv("price_taibao.csv", encoding='utf-8', index=True)

# %%
price_pufa = pd.DataFrame({})
#price_pufa = ts.get_k_data('600000',start='2008-01-01')#2423
price_pufa = ts.get_hist_data('600000')#2423
price_pufa.to_csv("price_pufa.csv", encoding='utf-8', index=True)
